# %% [markdown]
# <h1>Run the experiment on CoLab</h1>

# %%
# !git clone https://github.com/kristigjerko301101/aml_project.git && cd aml_project && git checkout master

# %%
# !cd aml_project && python ./data/run.py --dataset cifar100 --root ./data --alpha 0.5

# %%
# !pip install wandb

# %%
import os
os.environ["WANDB_API_KEY"] = ""
os.environ["WANDB_MODE"] = "online"

# %%
# !wandb login --cloud "API_KEY"

# %%
# !cd aml_project && python run_scaffold.py --dataset cifar100 \
--global_epochs 2000 --local_epochs 1 --local_lr 0.1 --batch_size 128 --client_num_per_round 5 --save_period 1000 --verbose_gap 100
